# %% [markdown]
# Эта тетрадь представляет собой упражнение из курса "Введение в машинное обучение". Вы можете ознакомиться с учебным пособием по этой ссылке.

# %% [markdown]
# # Вступление
#
# В этом упражнении вы создадите и отправите прогнозы для конкурса Kaggle. Затем вы можете улучшить свою модель (например, добавив дополнительные функции), чтобы применить полученные знания и подняться в таблице лидеров.
#
# Начните с запуска приведенной ниже ячейки кода, чтобы настроить проверку кода и пути к файлам для набора данных.

# %%
# Настройка проверки кода
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex7 import *

# Настройка путей к файлам
import os
if not os.path.exists("../input/train.csv"):
    os.symlink("../input/home-data-for-ml-course/train.csv", "../input/train.csv")  
    os.symlink("../input/home-data-for-ml-course/test.csv", "../input/test.csv")

# %% [markdown]
# Вот часть кода, который вы уже написали. Для начала запустите его еще раз.

# %%
# Импорт полезных библиотек
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# Загрузите данные и отделите целевой объект
iowa_file_path = '../input/train.csv'
home_data = pd.read_csv(iowa_file_path)
y = home_data.SalePrice

# Создайте X (После выполнения упражнения вы можете вернуться и изменить эту строку!)
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']

# Выберите столбцы, соответствующие объектам, и просмотрите данные
X = home_data[features]
X.head()

# Разделить на данные для проверки и обучения
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# Определите модель случайного леса
rf_model = RandomForestRegressor(random_state=1)
rf_model.fit(train_X, train_y)
rf_val_predictions = rf_model.predict(val_X)
rf_val_mae = mean_absolute_error(rf_val_predictions, val_y)

print("Validation MAE for Random Forest Model: {:,.0f}".format(rf_val_mae))

# %% [markdown]
# # Подготовьте модель для соревнований
#
# Приведенная выше кодовая ячейка обучает модель случайного леса на train_X и train_your.
#
# Используйте приведенную ниже кодовую ячейку, чтобы построить модель случайного леса и обучить ее на всех X и y.

# %%
# Чтобы повысить точность, создайте новую модель случайного леса, которую вы будете тренировать на всех обучающих данных.
rf_model_on_full_data = ____

# сопоставить rf_model_on_full_data со всеми данными из обучающих данных
____

# %% [markdown]
# Теперь прочтите файл с "тестовыми" данными и примените свою модель для составления прогнозов.

# %%
# путь к файлу, который вы будете использовать для прогнозов
test_data_path = '../input/test.csv'

# чтение файла тестовых данных с помощью pandas
test_data = ____

# создайте test_X, который берется из test_data, но включает только те столбцы, которые вы использовали для прогнозирования.
# Список столбцов хранится в переменной с именем features
test_X = ____

# делайте прогнозы, которые мы вам представим. 
test_preds = ____

# %% [markdown]
# Перед отправкой выполните проверку, чтобы убедиться, что ваши test_preds имеют правильный формат.

# %% [markdown]
# # Создайте заявку
#
# Введите код в ячейку ниже, чтобы сгенерировать CSV-файл с вашими прогнозами, который вы можете использовать для отправки на конкурс.

# %%
# Запустите код для сохранения прогнозов в формате, используемом для подсчета очков в соревнованиях.

output = pd.DataFrame({'Id': test_data.Id,
                       'SalePrice': test_preds})
output.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 # Запустите код для сохранения прогнозов в формате, используемом для подсчета очков в соревнованиях.
# ----> 3 output = pd.DataFrame({'Id': test_data.Id,
#       4                        'SalePrice': test_preds})
#       5 output.to_csv('submission.csv', index=False)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Подайте заявку на участие в конкурсе
#
# Чтобы проверить свои результаты, вам необходимо присоединиться к конкурсу (если вы еще этого не сделали). Откройте новое окно, перейдя по этой ссылке. Затем нажмите на кнопку Присоединиться к конкурсу.
# ![image.png](attachment:image.png)
# Далее следуйте приведенным ниже инструкциям:
#
# Для начала нажмите на кнопку Сохранить версию в правом верхнем углу окна. Откроется всплывающее окно.
# Убедитесь, что выбран параметр Сохранить и запустить все, а затем нажмите на кнопку Сохранить.
# В результате в левом нижнем углу записной книжки откроется окно. После завершения работы нажмите на цифру справа от кнопки Сохранить версию. В правой части экрана появится список версий. Нажмите на многоточие (...) справа от самой последней версии и выберите Открыть в программе просмотра. После этого вы перейдете в режим просмотра той же страницы. Вам нужно будет прокрутить страницу вниз, чтобы вернуться к этим инструкциям.
# Перейдите на вкладку "Данные" в верхней части экрана. Затем выберите файл, который вы хотите отправить, и нажмите кнопку "Отправить", чтобы добавить свои результаты в таблицу лидеров.
# Теперь вы успешно приняли участие в конкурсе!
#
# Если вы хотите продолжить работу над улучшением своей производительности, нажмите кнопку "Редактировать" в правом верхнем углу экрана. Затем вы можете изменить свой код и повторить процесс. Есть много возможностей для улучшения, и по мере работы вы будете подниматься в таблице лидеров.
#
# # Продолжайте прогрессировать
#
# Существует множество способов улучшить вашу модель, и экспериментирование - отличный способ научиться на этом этапе.
#
# Лучший способ улучшить вашу модель - это добавить функции. Чтобы добавить дополнительные функции к данным, вернитесь к первой ячейке кода и измените эту строку кода, добавив в нее больше имен столбцов:
#
# характеристики = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'Полная ванная комната', 'Спальня', 'Общая площадь']
# Некоторые функции могут вызывать ошибки из-за таких проблем, как пропущенные значения или нечисловые типы данных. Вот полный список потенциальных столбцов, которые вы, возможно, захотите использовать и которые не будут вызывать ошибок:
#
# 'MSSubClass'
# "LotArea"
# "Общее качество"
# "Общее количество"
# "Год постройки"
# "Год обновления"
# "1stFlrSF"
# '2ndFlrSF"
# "Низкий уровень качества"
# "Гостиная"
# , "Полная ванная"
# "Небольшая ванная"
# "Спальня"
# , "Кухня"
# "Общая ванная"
# "Камины"
# "Деревянные веранды"
# "OpenPorchSF"
# "Закрытый порт"
# "3SsnPorch"
# "Экранный порт"
# "PoolArea"
# "MiscVal"
# "MoSold"
# "YrSold"
# Просмотрите список столбцов и подумайте о том, что может повлиять на цены на жилье. Чтобы узнать больше о каждой из этих функций, ознакомьтесь с описанием данных на странице конкурса.
#
# После обновления приведенной выше ячейки кода, определяющей функции, повторно запустите все ячейки кода, чтобы оценить модель и сгенерировать новый файл для отправки.
#
# # Что дальше?
#
# Как упоминалось выше, некоторые функции будут выдавать ошибку, если вы попытаетесь использовать их для обучения своей модели. Промежуточный курс машинного обучения научит вас, как работать с такими функциями. Вы также научитесь использовать xgboost, метод, обеспечивающий еще большую точность, чем Random Forest.
#
# Курс Pandas даст вам навыки манипулирования данными, которые позволят быстро перейти от концептуальной идеи к реализации в ваших проектах в области науки о данных.
#
# Вы также готовы к курсу глубокого обучения, на котором вы будете создавать модели с более высокой производительностью, чем у человека, в задачах компьютерного зрения.
