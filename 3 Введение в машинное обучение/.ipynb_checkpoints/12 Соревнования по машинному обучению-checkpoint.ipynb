# %% [markdown]
# # Соревнования по машинному обучению
# Участвуйте в соревнованиях по машинному обучению, чтобы постоянно совершенствоваться и видеть свой прогресс.

# %% [markdown]
# Соревнования по машинному обучению - отличный способ улучшить свои навыки работы с данными и оценить свой прогресс.
#
# В следующем упражнении вы создадите и отправите прогнозы для конкурса цен на жилье для пользователей Kaggle Learn.
# ![image.png](attachment:image.png)

# %% [markdown]
# # ваш ход¶
# Используйте то, чему вы научились на курсе, чтобы создать заявку на участие в конкурсе Kaggle!
