# %% [markdown]
# Эта тетрадь представляет собой упражнение из курса "Введение в машинное обучение". Вы можете ознакомиться с учебным пособием по этой ссылке.

# %% [markdown]
# # Резюмировать
#
# На данный момент вы загрузили свои данные и просмотрели их с помощью следующего кода. Запустите эту ячейку, чтобы настроить среду программирования с того места, на котором был остановлен предыдущий шаг.

# %% [markdown]
# # Упражнения
#
# Шаг 1: Укажите цель прогнозирования
#
# Выберите целевую переменную, которая соответствует цене продажи. Сохраните ее в новой переменной с именем y. Вам нужно будет распечатать список столбцов, чтобы найти название нужного вам столбца.

# %%
# распечатайте список столбцов в наборе данных, чтобы найти имя объекта прогнозирования.

# %%
y = ____

# %%
# В строках ниже вы найдете подсказку или решение.
# шаг_1.подсказка() 
# шаг_1.решение()

# %% [markdown]
# # Шаг 2: Создайте
#
# Теперь вы создадите фрейм данных с именем X, содержащий функции прогнозирования.
#
# Поскольку вам нужны только некоторые столбцы из исходных данных, сначала вы создадите список с именами столбцов, которые вам нужны в X.
#
# Вы будете использовать только следующие столбцы в списке (вы можете скопировать и вставить весь список целиком, чтобы сэкономить на вводе текста, хотя вам все равно придется добавить кавычки):
#
# Площадь участка
# Год постройки
# 1-й квартал Южной Америки
# 2-й квартал Южной Америки
# Полная ванна
# BedroomAbvGr
# TotRmsAbvGrd
# После того, как вы создали этот список объектов, используйте его для создания фрейма данных, который вы будете использовать для соответствия модели.

# %%
# Создайте список функций, приведенный ниже.
feature_names = ___

# Выберите данные, соответствующие объектам в поле feature_names.
X = ____

# %% [markdown]
# # Просмотрите данные
#
# Перед построением модели взгляните на X, чтобы убедиться, что она выглядит разумно

# %%
# Просмотреть данные
# распечатать описание или статистику из X
#распечатать(_)

# напечатать несколько верхних строк
#распечатать(_)

# %% [markdown]
# # Шаг 3: Укажите и подгоните модель
#
# Создайте DecisionTreeRegressor и сохраните его как iowa_model. Убедитесь, что вы выполнили соответствующий импорт из sklearn, чтобы запустить эту команду.
#
# Затем подгоните модель, которую вы только что создали, используя данные в X и y, которые вы сохранили выше.

# %%
# from _ import _
#укажите модель. 
#Для воспроизводимости модели задайте числовое значение для параметра random_state при указании модели
iowa_model = ____

# Соответствует модели
____

# %% [markdown]
# # Шаг 4: Сделайте прогнозы
#
# Сделайте прогнозы с помощью команды модели predict, используя X в качестве данных. Сохраните результаты в переменной с именем predicts.

# %%
predictions = ____
print(predictions)

# %% [markdown]
# # Подумайте о своих результатах
#
# Используйте метод head, чтобы сравнить несколько лучших прогнозов с фактическими ценами на жилье (в y) для тех же домов. Есть что-нибудь удивительное?

# %%
# Вы можете написать код в этой ячейке

# %% [markdown]
# Естественно спросить, насколько точными будут прогнозы модели и как вы можете их улучшить. Это будет ваш следующий шаг.
#
# # продолжай
#
# Вы готовы к валидации модели.
