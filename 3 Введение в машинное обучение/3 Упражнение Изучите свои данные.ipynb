# %% [markdown]
# Это упражнение проверит вашу способность читать файл данных и понимать статистику о данных.
#
# В последующих упражнениях вы будете применять методы фильтрации данных, создавать модель машинного обучения и последовательно улучшать свою модель.
#
# В примерах курса используются данные из Мельбурна. Чтобы убедиться, что вы можете применять эти методы самостоятельно, вам нужно будет применить их к новому набору данных (с ценами на жилье в Айове).
#
# В упражнениях используется среда программирования "записная книжка". Если вы не знакомы с записными книжками, у нас есть 90-секундное вступительное видео.
#
# # Упражнения
#
# Запустите следующую ячейку, чтобы настроить проверку кода, которая будет проверять вашу работу по мере продвижения.

# %% [markdown]
# # Шаг 1: Загрузка данных
#
# Считываем файл данных из Iowa во фрейм данных Pandas с именем home_data.

# %%
import pandas as pd

# Path of the file to read
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

# Fill in the line below to read the file into a variable home_data
home_data = ____

# %% [markdown]
# # Шаг 2: Просмотрите данные
#
# Используйте изученную команду для просмотра сводной статистики данных. Затем введите переменные, чтобы ответить на следующие вопросы

# %%
# Напечатать сводную статистику в следующей строке
____

# %%
# Каков средний размер лота (округленный до ближайшего целого числа)?
avg_lot_size = ____

# Сколько лет самому новому дому на сегодняшний день (текущий год - дата, когда он был построен)
newest_home_age = ____

# %% [markdown]
# # Подумайте о своих данных
#
# Самый новый дом в ваших данных не такой уж и новый. Этому есть несколько возможных объяснений:
#
# Там, где были собраны эти данные, не строили новых домов.
# Данные были собраны очень давно. Дома, построенные после публикации данных, не отображались.
# Если причиной является объяснение № 1, приведенное выше, влияет ли это на ваше доверие к модели, которую вы строите на основе этих данных? А что, если это причина № 2?
#
# Как вы могли бы разобраться в данных, чтобы понять, какое объяснение более правдоподобно?
#
# Ознакомьтесь с этой темой обсуждения, чтобы узнать, что думают другие, или добавить свои идеи.
#
# # продолжай
#
# Вы готовы к своей первой модели машинного обучения.
