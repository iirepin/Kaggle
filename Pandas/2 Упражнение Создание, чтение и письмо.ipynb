# %% [markdown]
# # Упражнение: Создание, чтение и письмо

# %% [markdown]
# Эта тетрадь представляет собой упражнение из курса "Панды". Вы можете ознакомиться с учебным пособием по этой ссылке.

# %% [markdown]
# # Вступление
#
# Первым шагом в большинстве проектов по анализу данных является чтение файла данных. В этом упражнении вы создадите объекты Series и DataFrame как вручную, так и путем чтения файлов данных.
#
# Запустите приведенную ниже ячейку кода, чтобы загрузить библиотеки, которые вам понадобятся (включая код для проверки ваших ответов).

# %%
import pandas as pd
pd.set_option('display.max_rows', 5)
from learntools.core import binder; binder.bind(globals())
from learntools.pandas.creating_reading_and_writing import *
print("Setup complete.")

# %% [markdown]
# # Упражнения

# %% [markdown]
# # 1.
#
# В приведенной ниже ячейке создайте фрейм данных fruits, который выглядит следующим образом:

# %%
# Ваш код находится здесь. Создайте фрейм данных, соответствующий приведенной выше диаграмме, и назначьте его переменной fruits.
fruits = ____

# %% [markdown]
# # 2.
#
# Создайте фрейм данных fruit_sales, который соответствует приведенной ниже диаграмме:

# %%
# Ваш код находится здесь. Создайте фрейм данных, соответствующий приведенной выше диаграмме, и присвойте его переменной fruit_sales.
fruit_sales = ____

# %% [markdown]
# # 3.
#
# Создайте набор ингредиентов, который будет выглядеть следующим образом::
#
# Мука - 4 стакана
# Молоко - 1 стакан
# Яйца - 2 больших
# Спам- 1 банка
# Название: Ужин, тип: объект

# %%
ingredients = ____

# %% [markdown]
# # 4.
#
# Преобразуйте следующий набор данных отзывов о вине в формате csv во фрейм данных под названием reviews:
# ![image-2.png](attachment:image-2.png)
# Путь к файлу csv таков ../input/wine-reviews/winemag-data_first 150k.csv. Первые несколько строк выглядят следующим образом:
#
# ,страна,описание,обозначение,баллы,цена,провинция,регион_1,регион_2,сорт,винодельня
# 0,США, "Это потрясающее 100% сортовое вино[...]",Мартас-Винъярд,96,235,0,Калифорния,Долина Напа,Napa,Каберне Совиньон,Хайц
# 1,Испания, "Ароматы спелого инжира, ежевики и[...]",Carodorum Selección Especial Reserve,96,110,0,Северная Испания,Торо,Тинта-де-Торо,Бодега Кармен Родригес

# %%
reviews = ____

# %% [markdown]
# # 5.
#
# Запустите приведенную ниже ячейку, чтобы создать и отобразить фрейм данных под названием animals:

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals

# %% [markdown]
# В ячейке ниже напишите код для сохранения этого фрейма данных на диск в виде csv-файла с именем cows_and_goats.csv.

# %%
# Ваш код находится здесь

# %% [markdown]
# # Продолжай
#
# Переходите к изучению вопросов индексации, выбора и назначения.
