# %% [markdown]
# # Упражнение: Индексация, выбор и назначение

# %% [markdown]
# Эта тетрадь представляет собой упражнение из курса "Панды". Вы можете ознакомиться с учебным пособием по этой ссылке.

# %% [markdown]
# # Вступление
#
# В этом наборе упражнений мы будем работать с набором данных о винных отзывах.

# %% [markdown]
# Просмотрите обзор ваших данных, выполнив следующую строку.

# %%
reviews.head()

# %% [markdown]
# # Упражнения
# # 1.
#
# Выберите столбец "Описание" в разделе "Отзывы" и присвойте результат переменной "описание".

# %%
# Ваш код здесь
desc = ____

# %% [markdown]
# Дополнительный вопрос: к какому типу объектов относится desc? Если вы не уверены, вы можете проверить, вызвав функцию type в Python: type(desc).

# %% [markdown]
# # 2.
#
# Выберите первое значение из столбца описания отзывов, присвоив его переменной first_description.

# %%
first_description = ____

# %% [markdown]
# # 3.
#
# Выберите первую строку данных (первую запись) из отзывов, присвоив ей переменную first_row.

# %%
first_row = ____

# %% [markdown]
# # 4.
#
# Выберите первые 10 значений из столбца описания в обзорах, присвоив результат переменной first_descriptions.
#
# Совет: отформатируйте свои выходные данные в виде серии pandas.

# %%
first_descriptions = ____

# %% [markdown]
# # 5.
#
# Выберите записи с индексными метками 1, 2, 3, 5 и 8, присвоив результат переменной sample_reviews.
#
# Другими словами, сгенерируйте следующий фрейм данных:
# ![image.png](attachment:image.png)

# %%
sample_reviews = ____

# %% [markdown]
# # 6.
#
# Создайте переменную df, содержащую столбцы country, province, region_1 и region_2 записей с индексными метками 0, 1, 10 и 100. Другими словами, создайте следующий фрейм данных:
# ![image.png](attachment:image.png)

# %%
df = ____

# %% [markdown]
# 7.
#
# Создайте переменную df, содержащую столбцы country и variety для первых 100 записей.
#
# Подсказка: вы можете использовать loc или iloc. При работе над ответом на этот вопрос и несколько последующих учитывайте следующие "нюансы", описанные в руководстве.:
#
# iloc использует схему индексации Python stdlib, в которой включается первый элемент диапазона и исключается последний.  loc, тем временем, индексирует все включительно.
#
# Это особенно сбивает с толку, когда индекс фрейма данных представляет собой простой числовой список, например, 0,...,1000. В этом случае df.iloc[0:1000] вернет 1000 записей, в то время как df.loc[0:1000] вернет 1001 из них! Чтобы получить 1000 элементов с помощью loc, вам нужно будет перейти на один уровень ниже и запросить df.iloc[0:999].

# %%
df = ____

# %% [markdown]
# # 8.
#
# Создайте фрейм данных italian_wines, содержащий отзывы о винах, произведенных в Италии. Подсказка: отзывы.страна - это что?

# %%
italian_wines = ____

# %% [markdown]
# # 9.
#
# Создайте базу данных top_oceania_wines, содержащую все отзывы о винах из Австралии или Новой Зеландии, набравшие не менее 95 баллов (из 100 возможных).

# %%
top_oceania_wines = ____

# %% [markdown]
# # Продолжай
#
# Переходите к изучению сводных функций и карт.
