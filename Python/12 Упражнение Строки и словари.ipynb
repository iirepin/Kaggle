# %% [markdown]
# Вы почти закончили изучение курса. Отличная работа!
#
# У нас есть для вас еще пара интересных задач, прежде чем вы продолжите.
#
# Как всегда, перед началом работы над вопросами запустите приведенный ниже установочный код.

# %% [markdown]
# Давайте начнем с сильного удара молнии, чтобы разогреться. Какова длина строк, приведенных ниже?
#
# Для каждой из пяти строк, приведенных ниже, спрогнозируйте, что вернет функция len() при передаче этой строки. Используйте переменную длину, чтобы записать свой ответ, затем запустите ячейку, чтобы проверить, были ли вы правы.
#
# # 0a.

# %%
a = ""
length = ____
q0.a.check()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 a = ""
# ----> 2 length = ____
#       3 q0.a.check()
#
# NameError: name '____' is not defined

# %% [markdown]
# # 0b.

# %%
b = "it's ok"
length = ____
q0.b.check()

# %% [markdown]
# # 0c.

# %%
c = 'it\'s ok'
length = ____
q0.c.check()

# %% [markdown]
# # 0d.

# %%
d = """hey"""
length = ____
q0.d.check()

# %% [markdown]
# # 0e.

# %%
e = '\n'
length = ____
q0.e.check()

# %% [markdown]
# # 1.
#
# Есть поговорка, что "специалисты по обработке данных тратят 80% своего времени на очистку данных и 20% - на жалобы по поводу очистки данных". Давайте посмотрим, сможете ли вы написать функцию, которая поможет очистить данные о почтовом индексе США. При наличии строки он должен возвращать значение, соответствует ли эта строка действительному почтовому индексу. Для наших целей действительным почтовым индексом является любая строка, состоящая ровно из 5 цифр.
#
# ПОДСКАЗКА: в str есть метод, который будет полезен здесь. Используйте справку(str), чтобы просмотреть список строковых методов.

# %%
def is_valid_zip(zip_code):
    """Returns whether the input string is a valid (5 digit) zip code
    """
    pass

# %% [markdown]
# # 2.
#
# Исследователь собрала тысячи новостных статей. Но она хочет сосредоточить свое внимание на статьях, содержащих определенное слово. Воспользуйтесь приведенной ниже функцией, которая поможет ей отфильтровать список статей.
#
# Ваша функция должна соответствовать следующим критериям:
#
# Не включайте документы, в которых строка с ключевым словом отображается только как часть более крупного слова. Например, если бы она искала ключевое слово “закрыто”, вы бы не включили строку “вложено”.
# Она не хочет, чтобы вы различали заглавные и строчные буквы. Поэтому фраза “Закрыли регистр” будет использоваться, когда ключевое слово “закрыто”
# Не допускайте, чтобы точки или запятые влияли на соответствие. “Оно закрыто”. будет добавляться, если ключевое слово “закрыто”. Но вы можете предположить, что других типов знаков препинания не существует.

# %%
def word_search(doc_list, keyword):
    """
    Получает список документов (каждый документ представляет собой строку) и ключевое слово. 
    Возвращает список значений индекса в исходный список для всех документов
, содержащих ключевое слово.

    Пример:
    doc_list = ["Казино Learn Python Challenge", "Они купили машину", "Casinoville"]
    >>> поиск слов(doc_list, "казино")
    >>> [0]
    """
    pass

# %% [markdown]
# # 3.
#
# Теперь исследователь хочет ввести несколько ключевых слов для поиска. Чтобы помочь ему, выполните приведенную ниже функцию.
#
# (При реализации этой функции рекомендуется использовать функцию word_search, которую вы только что написали. Повторное использование кода таким образом делает ваши программы более надежными и удобочитаемыми - и экономит время на вводе текста!)

# %%
def multi_word_search(doc_list, keywords):
    """
    Принимает список документов (каждый документ представляет собой строку) и список ключевых слов.  
    Возвращает словарь, где каждый ключ является ключевым словом, а значение - списком индексов
    (из doc_list) документов, содержащих это ключевое слово

    >>>>>> список документов = ["Казино Learn Python Challenge", "Они купили машину и казино", "Casino ville"]
    >>> ключевые слова = ["казино", "они"]
    >>> поиск по нескольким словарям(список документов, ключевые слова)
    {'казино': [0, 1], 'они': [1]}
    """
    pass

# %% [markdown]
# # продолжай
#
# Вы многому научились. Но даже лучшие программисты в значительной степени полагаются на "библиотеки" кода других программистов. Вы узнаете об этом на последнем уроке.
