# %% [markdown]
# Добро пожаловать на курс «Введение в программирование»! Этот курс для вас, если вы никогда не писали ни одной строки кода, и вы заинтересованы в изучении науки о данных и машинного обучения. (Если у вас есть опыт программирования и вы только новичок в языке Python, курс Python лучше подходит для начала работы.)
#
# В этом курсе вы узнаете, как использовать код, чтобы заставить компьютер выполнять определенные задачи за вас. Python является одним из самых популярных языков программирования для науки о данных, и это язык, который вы изучите на этом курсе. После завершения этого курса вы будете полностью готовы к проходу на курс Python, за которым следует курс «Введение в машинное обучение».
#
# В этом руководстве вы увидите несколько примеров кода Python. У вас будет возможность написать свой собственный код в упражнении. (Если вы хотите просмотреть упражнение, не стесняйтесь взглянуть сейчас. Мы также предоставляем ссылку на упражнение в конце этого урока.)

# %% [markdown]
# Печать¶

# %% [markdown]
# Один из самых простых (и самых важных!) задачи, которые вы можете попросить компьютер выполнить, - это печать сообщения.
#
# In Python, we ask a computer to print a message for us by writing print() and putting the message inside the parentheses and enclosed in quotation marks. Below, we ask the computer to print the message Hello, world!.

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# Код находится внутри коробки (известной как ячейка кода), а ответ компьютера (называемый выводом кода) показан под окном. Как видите, компьютер напечатал сообщение, которое мы хотели.

# %% [markdown]
# Арифметика

# %% [markdown]
# Мы также можем напечатать значение некоторой арифметической операции (например, сложение, вычитание, умножение или деление).
#
# Например, в следующей ячейке кода компьютер добавляет 2 к 1, а затем печатает результат, который составляет 3. Обратите внимание, что в отличие от того, когда мы просто печатали текст, мы не используем никаких кавычек.

# %% [markdown]
# Мы также можем сделать вычитание в Python. Следующая ячейка кода вычитает 5 из 9 и печатает результат, который составляет 4.

# %% [markdown]
# Вы действительно можете сделать много вычислений с помощью Python! Некоторые примеры см. в таблице ниже.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вы можете управлять порядком операций в длинных расчетах с помощью скобок.

# %% [markdown]
# В целом, Python следует правилу PEMDAS при определении порядка операций.

# %% [markdown]
# # Комментарии
# Мы используем комментарии, чтобы аннотировать, что делает код. Они помогают другим людям понять ваш код, а также могут быть полезны, если вы давно не смотрели на свой собственный код. До сих пор код, который мы написали, очень короткий, но аннотации становятся более важными, когда вы написали много кода.
#
# For instance, in the next code cell, we multiply 3 by 2. We also add a comment (# Multiply 3 by 2) above the code to describe what the code is doing.
