# %% [markdown]
# Титаник - Машинное обучение на примере катастрофы
# Начните прямо сейчас! Узнайте, как выжить на "Титанике", и познакомьтесь с основами ML
# # Обзор
# Это соревнование проводится на неопределенный срок с постоянной таблицей лидеров. Учить больше
# Ведущий конкурса
# Kaggle
# Призы и награды
# Знания
# Не начисляет очков или медалей
# Участие
# 1 344 350 Участников
# 14 366 Участниц
# 14 096 Команд
# подали 60 460 заявок
# Теги
#
# Ссылка на описание
# keyboard_arrow_up
# 👋🛳️ Привет, добро пожаловать в Kaggle! Вы находитесь в правильном месте.
#
# Это легендарный конкурс Titanic ML competition – лучшее, первое испытание для вас, позволяющее погрузиться в соревнования по ML и ознакомиться с тем, как работает платформа Kaggle.
#
# Если вы хотите обсудить этот конкурс с другими пользователями, присоединяйтесь к нашему дискорду! У нас есть каналы для проведения конкурсов, объявлений о вакансиях и обсуждений карьеры, ресурсы и общение с вашими коллегами-специалистами по обработке данных. Перейдите по ссылке здесь: https://discord.gg/kaggle
#
# Суть конкурса проста: с помощью машинного обучения создать модель, которая предсказывает, какие пассажиры выжили после крушения "Титаника".
#
# Читайте дальше или смотрите видео ниже, чтобы узнать больше подробностей. Как только вы будете готовы к участию в конкурсе, нажмите на кнопку "Присоединиться к конкурсу", чтобы создать учетную запись и получить доступ к данным о конкурсе. Затем ознакомьтесь с руководством Алексиса Кука "Титаник", в котором шаг за шагом рассказывается, как подать свою первую заявку!

# %% [markdown]
# Задача номер один
#
# Крушение "Титаника" - одно из самых печально известных кораблекрушений в истории.
#
# 15 апреля 1912 года, во время своего первого рейса, судно, считавшееся “непотопляемым”, затонуло после столкновения с айсбергом. К сожалению, на борту не хватило спасательных шлюпок для всех, что привело к гибели 1502 из 2224 пассажиров и членов экипажа.
#
# Хотя в выживании был определенный элемент везения, похоже, что у некоторых групп людей было больше шансов выжить, чем у других.
#
# В этом задании мы просим вас построить прогностическую модель, которая ответит на вопрос: “У каких людей было больше шансов выжить?”, используя данные о пассажирах (например, имя, возраст, пол, социально-экономический класс и т.д.).
#
# Рекомендуемое руководство
#
# Мы настоятельно рекомендуем учебник Алексиса Кука "Титаник", в котором шаг за шагом рассказывается о том, как сделать свою первую заявку, и этот блокнот для начинающих, чтобы начать работу.
# Как работают конкурсы Kaggle
#
# Присоединяйтесь к конкурсу
# Ознакомьтесь с описанием конкурса, примите правила конкурса и получите доступ к набору данных о конкурсе.
# Приступайте к работе
# Загрузите данные, постройте на их основе модели локально или в Kaggle Notebooks (нашей простой в настройке среде Jupyter Notebooks с бесплатными графическими процессорами) и сгенерируйте файл прогноза.
# Отправьте заявку
# Загрузите свой прогноз в виде заявки на Kaggle и получите оценку точности.
# Проверьте таблицу лидеров
# Посмотрите, как ваша модель соотносится с другими участниками Kaggle в нашей таблице лидеров.
# Улучшите свой результат
# Посетите дискуссионный форум, чтобы найти множество руководств и советов от других конкурентов.
# Видео о жаргоне Kaggle
#
# Изучая дискуссионные форумы и общедоступные блокноты Kaggle, вы можете столкнуться с незнакомым жаргоном. Посмотрите видео доктора Рэйчел Татман о Kaggle Lingo, чтобы быть в курсе событий!
# Какие данные я буду использовать в этом конкурсе?
#
# В этом конкурсе вы получите доступ к двум аналогичным наборам данных, которые содержат информацию о пассажирах, такую как имя, возраст, пол, социально-экономический класс и т.д. Один набор данных называется train.csv, а другой - test.csv.
#
# Файл Train.csv будет содержать подробную информацию о группе пассажиров, находившихся на борту (точнее, о 891 пассажире), и, что немаловажно, покажет, выжили они или нет, что также известно как “основная правда”.
#
# Набор данных test.csv содержит аналогичную информацию, но не раскрывает “основную правду” о каждом пассажире. Ваша задача - предсказать эти результаты.
#
# Используя шаблоны, которые вы найдете в данных train.csv, спрогнозируйте, выжили ли остальные 418 пассажиров, находившихся на борту (найдены в test.csv).
#
# Перейдите на вкладку “Данные”, чтобы подробнее изучить наборы данных. Как только вы почувствуете, что создали конкурентоспособную модель, отправьте ее в Kaggle, чтобы узнать, на каком месте ваша модель находится в нашей таблице лидеров по сравнению с другими разработчиками.
#
# Как отправить свой прогноз в Kaggle
#
# Как только вы будете готовы, отправьте заявку и попадите в таблицу лидеров:
#
# Нажмите на кнопку “Отправить прогнозы”.

# %% [markdown]
# ![image.png](attachment:image.png)
# Загрузите файл CSV в формате файла для отправки. Вы можете отправлять 10 заявок в день.
# ![image-2.png](attachment:image-2.png)
# Формат файла для отправки:
#
# Вы должны отправить файл csv, содержащий ровно 418 записей плюс строку заголовка. При отправке будет отображаться ошибка, если у вас будут дополнительные столбцы (помимо PassengerId и Survived) или строк.
#
# В файле должно быть ровно 2 столбца:
#
# Идентификатор пассажира (отсортирован в произвольном порядке)
# Выживший (содержит ваши бинарные прогнозы: 1 для выжившего, 0 для погибшего)
# Понял! Я готов приступить к работе. Где я могу получить помощь, если она мне понадобится?
#
# Для справки о конкурсе: Дискуссионный форум Titanic
# В Kaggle нет специальной команды, которая помогала бы устранять неполадки в вашем коде, поэтому, как правило, вы быстрее получаете ответ, задавая свой вопрос на соответствующем форуме. Форумы полны полезной информации о данных, показателях и различных подходах. Мы рекомендуем вам почаще посещать форумы. Если вы поделитесь своими знаниями, то увидите, что другие, в свою очередь, поделятся ими с вами!
#
# Последнее слово о записных книжках Kaggle
#
# Как мы упоминали ранее, Kaggle Notebooks - это наша простая в настройке и настраиваемая среда Jupyter Notebooks с бесплатными графическими процессорами и огромным хранилищем опубликованных сообществом данных и кода.
#
# На каждом соревновании вы найдете множество записных книжек с невероятной информацией. Это бесценный ресурс, с которым стоит ознакомиться. Ознакомьтесь с записными книжками этого конкурса здесь.
#
# 🏃♀Готовы к соревнованию? Присоединяйтесь к конкурсу здесь!

# %% [markdown]
# Ознакомительная
# ссылка
# keyboard_arrow_up
# Цель
#
# Ваша задача - предсказать, выжил ли пассажир во время крушения "Титаника" или нет.
# Для каждого из тестовых наборов вы должны предсказать значение переменной, равное 0 или 1.
#
# Метрический
#
# Ваша оценка - это процент правильно предсказанных пассажиров. Это называется точностью.
#
# Формат файла для отправки
#
# Вы должны отправить файл csv, содержащий ровно 418 записей плюс строку заголовка. В вашем сообщении будет отображена ошибка, если у вас есть дополнительные столбцы (помимо PassengerId и Survived) или строки.
#
# В файле должно быть ровно 2 столбца:
#
# Пассажиры (отсортированные в любом порядке).
# Выживший (содержит ваши двоичные прогнозы: 1 для выжившего, 0 для погибшего)
# Идентификатор пассажира, выживший
# 892,0
# 893,1
# 894,0
# И т.д.
# Вы можете загрузить пример файла для отправки (gender_submission.csv) на странице данных.

# %% [markdown]
# Часто задаваемые вопросы
# ссылка
# keyboard_arrow_up
# Что такое конкурс "Начало работы"?
#
# Конкурсы "Начало работы" были созданы специалистами по обработке данных Kaggle для людей, которые практически не имеют опыта работы с машинным обучением. Они - отличное место для начала, если вы новичок в науке о данных или только что закончили курс MOOC и хотите принять участие в Kaggle.
#
# Конкурсы "Начало работы" - это внеконкурсный способ познакомиться с платформой Kaggle, изучить основные концепции машинного обучения и начать знакомиться с людьми из сообщества. У них нет денежного приза, и они участвуют в розыгрыше по скользящей шкале.
#
# Как мне создать команду и управлять ею?
#
# Когда вы примете правила конкурса, команда будет создана для вас. Вы можете пригласить других участников в свою команду, согласиться на слияние с другой командой и обновить основную информацию, например название команды, перейдя на страницу "Дополнительно" > "Команда".
#
# Мы слышали от многих игроков, что объединение в команду - лучший способ научиться новым навыкам И весело провести время. Если у вас еще нет партнера по команде, подумайте о том, чтобы спросить, не хочет ли кто-нибудь присоединиться к команде на дискуссионном форуме.
#
# Что такое блокноты?
#
# Kaggle Notebooks - это облачная вычислительная среда, которая обеспечивает воспроизводимый и совместный анализ. Notebooks поддерживают сценарии на Python и R, Jupyter Notebooks и отчеты RMarkdown. Вы можете перейти на вкладку Notebooks, чтобы просмотреть весь общедоступный код для конкурса Titanic. Чтобы узнать больше о том, как использовать записные книжки для изучения науки о данных, ознакомьтесь с нашими курсами!
#
# Почему моя команда исчезла из списка лидеров?
#
# Чтобы соответствовать духу стартовых соревнований, мы ввели двухмесячный период для подачи заявок. Если заявка была подана более двух месяцев назад, она будет аннулирована и больше не будет учитываться в таблице лидеров.
#
# Если ваша команда не подавала заявок в течение предыдущих двух месяцев, она также будет исключена из таблицы лидеров. Это позволит сохранить размер таблицы лидеров на приемлемом уровне, освежит ее и не даст новичкам потеряться в море пропущенных баллов.
#
# "Я так усердно работал, чтобы набрать этот балл! Верните его!" Подробнее о нашем решении создать таблицу лидеров читайте здесь.
#
# Как мне связаться со службой поддержки?
#
# В Kaggle нет специальной службы поддержки, поэтому, как правило, вы быстрее получите ответ, задав свой вопрос на соответствующем форуме. (Для участия в этом конкурсе вам следует воспользоваться дискуссионным форумом Titanic).
#
# Служба поддержки может помочь только в решении проблем, с которыми сталкиваются все участники. Прежде чем обращаться в службу поддержки, пожалуйста, ознакомьтесь с информацией о вашей проблеме на форуме обсуждений. Если вы не можете найти ее, вы можете опубликовать сообщение о своей проблеме на форуме, чтобы другой участник или член команды Kaggle могли оказать помощь. Форумы полны полезной информации о данных, показателях и различных подходах. Мы рекомендуем вам почаще посещать форумы. Если вы поделитесь своими знаниями, вы увидите, что другие, в свою очередь, поделятся ими с вами!
#
# Если ваша проблема не устранена или кажется, что она эффективна для всех участников, пожалуйста, свяжитесь с нами.

# %% [markdown]
# Ссылка для цитирования
# : keyboard_arrow_up
# Уилл Кукирски. Титаник - машинное обучение после катастрофы. https://kaggle.com/competitions/titanic, 2012. Kaggle.
