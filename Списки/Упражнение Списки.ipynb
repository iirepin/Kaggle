# %% [markdown]
# Со списками все становится еще интереснее. Вы сможете применить свои новые знания для решения приведенных ниже вопросов. Не забудьте сначала запустить следующую ячейку.

# %% [markdown]
# # 1.
#
# Выполните приведенную ниже функцию в соответствии с ее строкой документации.

# %%
L = [1]

# %% [markdown]
# Подсказка: Python начинает отсчет с 0. Таким образом, второй элемент не индексируется с помощью 2

# %%
def select_second(L):
    """Возвращает второй элемент данного списка. Если в списке нет второго
элемента, верните None.
    """
    if len(L) < 2:
        return None
    return L[1]

# %%
select_second(L)

# %% [markdown]
# # 2.
#
# Вы анализируете спортивные команды. Состав каждой команды хранится в списке. Тренер - это первое имя в списке, капитан - второе имя в списке, а остальные игроки перечислены после него. Эти списки хранятся в другом списке, который начинается с лучшей команды и продолжается по списку до последней худшей команды. Выполните приведенную ниже функцию, чтобы выбрать капитана худшей команды.

# %%
def losing_team_captain(teams):
    """Получив список команд, где каждая команда представляет собой список имен, верните 2-го игрока (капитана)
    из последней команды в списке
    """
    return teams[-1][1]

# %% [markdown]
# # 3.
#
# В следующей версии Mario Kart появится новый предмет, который будет приводить в бешенство, - фиолетовый снаряд. При его использовании гонщик, занявший последнее место, становится первым, а гонщик, занявший первое место, - последним. Выполните описанную ниже функцию, чтобы реализовать эффект фиолетового снаряда.

# %%
def purple_shell(racers):
    """При наличии списка гонщиков установите для гонщика, занявшего первое место (в начале списка), последнее
    место и наоборот.
    
    >>> r = ["Марио", "Боузер", "Луиджи"]
    >>> пурпурная оболочка(r)
    >>> r
    ["Луиджи", "Боузер", "Марио"]
    """
    racers[0], racers[-1]=racers[-1], racers[0]

# %%
r = ["Марио", "Боузер", "Луиджи"]
purple_shell(r)
# Out:
# ['Луиджи', 'Боузер', 'Марио']

# %% [markdown]
# # 4.
#
# Какова длина следующих списков? Заполните переменные длины вашими прогнозами. (Попробуйте сделать прогноз для каждого списка, не вызывая для него функцию len().)

# %%
a = [1, 2, 3]
b = [1, [2, 3]]
c = []
d = [1, 2, 3][1:]

# Внесите свои прогнозы в список ниже. Длина должна содержать 4 числа, первое из которых
# - это длина a, второе - длина b и так далее.
lengths = []

# %%
len(a), len(b), len(c), len(d)
# Out:
# (3, 2, 0, 2)

# %%
print(d)
# Out:
# [2, 3]

# %% [markdown]
# о: В этом списке три элемента. Пока ничего сложного.
# б: Список [2, 3] считается одним элементом. Перед ним стоит один элемент. Таким образом, в списке 2 элемента.
# в: Пустой список содержит 0 элементов
# d: Выражение такое же, как и в списке [2, 3], который имеет длину 2.

# %% [markdown]
# # 5. 🌶️
#
# Мы используем списки, чтобы указать, кто присутствовал на нашей вечеринке, и в каком порядке они пришли. Например, в следующем списке представлена вечеринка с участием 7 гостей, на которую Адела пришла первой, а Форд - последним:
#
# party_attendees = ["Адела", "Фледа", "Оуэн", "Мэй", "Мона", "Гилберт", "Форд"]
# Гость считается "модно опоздавшим", если он прибыл позже, чем, по крайней мере, половина гостей вечеринки. Однако они не должны быть самыми последними гостями (это уже слишком). В приведенном выше примере Мона и Гилберт - единственные гости, которые опоздали по правилам моды.
#
# Воспользуйтесь приведенной ниже функцией, которая позволяет получить список участников вечеринки, а также человека, и сообщить нам, опаздывает ли этот человек по правилам моды.

# %%
arrivals = ["Адела", "Фледа", "Оуэн", "Мэй", "Мона", "Гилберт", "Форд"]

# %%
def fashionably_late(arrivals, name):
    """Получив список приглашенных на вечеринку и указав имя, уточните, опоздал ли гость с таким
именем по правилам приличия.
    """
    list_fashionably = arrivals[round(len(arrivals) / 2) : -1]
    if name in list_fashionably:
        return True
    else:
        return False
fashionably_late(arrivals, "Оуэн")
# Out:
# False

# %% [markdown]
# # продолжай
#
# Вот и все, что касается списков и кортежей! Теперь у вас есть базовые знания о циклах, и именно здесь списки и кортежи становятся по-настоящему интересными.
